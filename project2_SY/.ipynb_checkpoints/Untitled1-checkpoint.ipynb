# %%
import pandas as pd
from IPython.display import Image
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
cbData = {'$l_{max}$':[1000,2000,3000,4000,5000,6000,7000],
        'delta_ell':[6,6,7,10,12,15,17],
        'Mem [gb]':[1.6,6.2,16.1,38.5,69.8,121.7,174.2],
        'Time [min]':[0.2,0.8,4.4,9.4,17.8,75.3,104.5],
        'Mem scaling [*dell]':['-','-',1.87,3.25,5.46,'-','-'],
        'Time scaling [*dell]':['-','-',0.34,0.58,2.82,'-','-']}
 
df = pd.DataFrame(cbData)
df
# Out:
#    $l_{max}$  delta_ell  Mem [gb]  Time [min] Mem scaling [*dell]  \
# 0       1000          6       1.6         0.2                   -
# 1       2000          6       6.2         0.8                   -
# 2       3000          7      16.1         4.4                1.87
# 3       4000         10      38.5         9.4                3.25
# 4       5000         12      69.8        17.8                5.46
# 5       6000         15     121.7        75.3                   -
# 6       7000         17     174.2       104.5                   -
#
#   Time scaling [*dell]
# 0                    -
# 1                    -
# 2                 0.34
# 3                 0.58
# 4                 2.82
# 5                    -
# 6                    -
